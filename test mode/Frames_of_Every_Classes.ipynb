# %% [markdown]
# For Correct

# %%
import os
import cv2

def extract_frames(video_path, output_folder):
    # Open the video file
    video_capture = cv2.VideoCapture(video_path)

    # Get the video's frame rate
    fps = video_capture.get(cv2.CAP_PROP_FPS)

    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through all frames in the video and save them as images
    frame_number = 0
    while True:
        ret, frame = video_capture.read()
        if not ret:
            break

        frame_path = os.path.join(output_folder, f"frame_{frame_number}.jpg")
        cv2.imwrite(frame_path, frame)
        frame_number += 1

    # Release the video capture object
    video_capture.release()

if __name__ == "__main__":
    # Replace 'Correct' with the path to your folder containing the videos
    input_folder = "C:/Users/Lenovo/Desktop/koi bhi part 2/Videos/Correct/"
    # Replace 'frames_folder' with the path to the folder where you want to save the frames
    output_folder = "C:/Users/Lenovo/Desktop/koi bhi part 2/frames_folder"

    # List all the files in the input folder
    files = os.listdir(input_folder)

    # Loop through each file and extract frames from videos
    for file in files:
        video_path = os.path.join(input_folder, file)
        if file.lower().endswith((".mp4", ".avi", ".mkv")):
            extract_frames(video_path, output_folder)

# %%
import os
import cv2

def extract_frames(video_path, output_folder):
    # Open the video file
    video_capture = cv2.VideoCapture(video_path)

    # Get the video's frame rate
    fps = video_capture.get(cv2.CAP_PROP_FPS)

    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Get the filename without extension to use as a prefix for frames
    video_filename = os.path.splitext(os.path.basename(video_path))[0]

    # Loop through all frames in the video and save them as images
    frame_number = 0
    while True:
        ret, frame = video_capture.read()
        if not ret:
            break

        frame_path = os.path.join(output_folder, f"{video_filename}_frame_{frame_number}.jpg")
        cv2.imwrite(frame_path, frame)
        frame_number += 1

    # Release the video capture object
    video_capture.release()

if __name__ == "__main__":
    input_folder = "C:/Users/Lenovo/Desktop/koi bhi part 2/Videos/Correct/"
    # Replace 'frames_folder' with the path to the folder where you want to save the frames
    output_folder = "C:/Users/Lenovo/Desktop/koi bhi part 2/frames_folder"

    # List all the files in the input folder
    files = os.listdir(input_folder)

    # Loop through each file and extract frames from videos
    for file in files:
        video_path = os.path.join(input_folder, file)
        if file.lower().endswith((".mp4", ".avi", ".mkv")):
            extract_frames(video_path, output_folder)

# %% [markdown]
# For Incorrect

# %%
import os
import cv2

def extract_frames(video_path, output_folder):
    # Open the video file
    video_capture = cv2.VideoCapture(video_path)

    # Get the video's frame rate
    fps = video_capture.get(cv2.CAP_PROP_FPS)

    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Get the filename without extension to use as a prefix for frames
    video_filename = os.path.splitext(os.path.basename(video_path))[0]

    # Loop through all frames in the video and save them as images
    frame_number = 0
    while True:
        ret, frame = video_capture.read()
        if not ret:
            break

        frame_path = os.path.join(output_folder, f"{video_filename}_frame_{frame_number}.jpg")
        cv2.imwrite(frame_path, frame)
        frame_number += 1

    # Release the video capture object
    video_capture.release()

if __name__ == "__main__":
    # Replace 'incorrect' with the path to your main folder containing subfolders
    main_folder = "C:/Users/Lenovo/Desktop/koi bhi part 2/Videos/Incorrect/"
    # Replace 'frames_folder' with the path to the folder where you want to save the frames
    output_folder = "C:/Users/Lenovo/Desktop/koi bhi part 2/frames_folder1"

    # Loop through each subfolder in the main folder
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)
        if os.path.isdir(subfolder_path):
            # Loop through each video file in the subfolder
            for file in os.listdir(subfolder_path):
                video_path = os.path.join(subfolder_path, file)
                if file.lower().endswith((".mp4", ".avi", ".mkv")):
                    # Create a subfolder in the output folder to store frames of each subfolder
                    subfolder_output = os.path.join(output_folder, subfolder)
                    if not os.path.exists(subfolder_output):
                        os.makedirs(subfolder_output)
                    extract_frames(video_path, subfolder_output)

# %% [markdown]
# For None

# %%
import os
import cv2

def extract_frames(video_path, output_folder):
    # Open the video file
    video_capture = cv2.VideoCapture(video_path)

    # Get the video's frame rate
    fps = video_capture.get(cv2.CAP_PROP_FPS)

    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Get the filename without extension to use as a prefix for frames
    video_filename = os.path.splitext(os.path.basename(video_path))[0]

    # Loop through all frames in the video and save them as images
    frame_number = 0
    while True:
        ret, frame = video_capture.read()
        if not ret:
            break

        frame_path = os.path.join(output_folder, f"{video_filename}_frame_{frame_number}.jpg")
        cv2.imwrite(frame_path, frame)
        frame_number += 1

    # Release the video capture object
    video_capture.release()

if __name__ == "__main__":
    # Replace 'incorrect' with the path to your main folder containing subfolders
    main_folder = "C:/Users/Lenovo/Desktop/koi bhi part 2/Videos/None/"
    # Replace 'frames_folder' with the path to the folder where you want to save the frames
    output_folder = "C:/Users/Lenovo/Desktop/koi bhi part 2/frame_folders2"

    # Loop through each subfolder in the main folder
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)
        if os.path.isdir(subfolder_path):
            # Loop through each video file in the subfolder
            for file in os.listdir(subfolder_path):
                video_path = os.path.join(subfolder_path, file)
                if file.lower().endswith((".mp4", ".avi", ".mkv")):
                    # Create a subfolder in the output folder to store frames of each subfolder
                    subfolder_output = os.path.join(output_folder, subfolder)
                    if not os.path.exists(subfolder_output):
                        os.makedirs(subfolder_output)
                    extract_frames(video_path, subfolder_output)

    # Handle the "None" folder and its videos
    none_folder = "C:/Users/Lenovo/Desktop/koi bhi part 2/Videos/None/"
    none_output = os.path.join(output_folder, "None")
    if not os.path.exists(none_output):
        os.makedirs(none_output)

    for file in os.listdir(none_folder):
        video_path = os.path.join(none_folder, file)
        if file.lower().endswith((".mp4", ".avi", ".mkv")):
            extract_frames(video_path, none_output)

# %% [markdown]
# For Partially Correct

# %%
import os
import cv2

def extract_frames(video_path, output_folder):
    # Open the video file
    video_capture = cv2.VideoCapture(video_path)

    # Get the video's frame rate
    fps = video_capture.get(cv2.CAP_PROP_FPS)

    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Get the filename without extension to use as a prefix for frames
    video_filename = os.path.splitext(os.path.basename(video_path))[0]

    # Loop through all frames in the video and save them as images
    frame_number = 0
    while True:
        ret, frame = video_capture.read()
        if not ret:
            break

        frame_path = os.path.join(output_folder, f"{video_filename}_frame_{frame_number}.jpg")
        cv2.imwrite(frame_path, frame)
        frame_number += 1

    # Release the video capture object
    video_capture.release()

if __name__ == "__main__":
    # Replace 'incorrect' with the path to your main folder containing subfolders
    main_folder = "C:/Users/Lenovo/Desktop/koi bhi part 2/Videos/Partially correct"
    # Replace 'frames_folder' with the path to the folder where you want to save the frames
    output_folder = "C:/Users/Lenovo/Desktop/koi bhi part 2/frames_folder4"

    # Loop through each subfolder in the main folder
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)
        if os.path.isdir(subfolder_path):
            # Loop through each video file in the subfolder
            for file in os.listdir(subfolder_path):
                video_path = os.path.join(subfolder_path, file)
                if file.lower().endswith((".mp4", ".avi", ".mkv")):
                    # Create a subfolder in the output folder to store frames of each subfolder
                    subfolder_output = os.path.join(output_folder, subfolder)
                    if not os.path.exists(subfolder_output):
                        os.makedirs(subfolder_output)
                    extract_frames(video_path, subfolder_output)

    # Handle the "Partially_correct" folder and its subfolders
    partially_correct_folder = "C:/Users/Lenovo/Desktop/koi bhi part 2/Videos/Partially correct"

    for subfolder in os.listdir(partially_correct_folder):
        subfolder_path = os.path.join(partially_correct_folder, subfolder)
        if os.path.isdir(subfolder_path):
            # Loop through each video file in the subfolder
            for file in os.listdir(subfolder_path):
                video_path = os.path.join(subfolder_path, file)
                if file.lower().endswith((".mp4", ".avi", ".mkv")):
                    # Create a subfolder in the output folder to store frames of each subfolder
                    subfolder_output = os.path.join(output_folder, subfolder)
                    if not os.path.exists(subfolder_output):
                        os.makedirs(subfolder_output)
                    extract_frames(video_path, subfolder_output)
